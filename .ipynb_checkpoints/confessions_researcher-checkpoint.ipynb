# %%
import sqlite3

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect("backup/data.db")
q = "SELECT * FROM posts"
df = pd.read_sql_query(q, conn)
df.head()
# Out:
#    index  angry              created_time  haha  \
# 0      0    0.0  2018-02-14T09:50:00+0000  28.0
# 1      1    0.0  2018-02-14T09:40:00+0000   3.0
# 2      2    0.0  2018-02-14T09:30:00+0000   0.0
# 3      3    0.0  2018-02-14T09:20:03+0000  17.0
# 4      4    0.0  2018-02-14T09:20:00+0000   2.0
#
#                                 id  like  love  \
# 0  323288791493138_329592980862719  74.0   1.0
# 1  323288791493138_329590724196278  16.0   0.0
# 2  323288791493138_329592804196070  17.0   0.0
# 3  323288791493138_329598080862209  58.0   2.0
# 4  323288791493138_329590930862924   5.0   0.0
#
#                                              message parent_id  sad source  \
# 0  #1130 הדבר הכי מביך שקרה לי עד כה- ישבתי בספרי...      None  0.0   HUJI
# 1  #1129 גברים וגברות היום ולנטיינז, זה הרגע שלכם...      None  0.0   HUJI
# 2  #1128 לכל מי שמתרץ את עניין הרמאויות וההעתקות ...      None  0.0   HUJI
# 3                                       יוזמה נהדרת!      None  0.0   HUJI
# 4  #1127 אולי מישהו ירים כבר את הכפפה ויפתח קבוצת...      None  0.0   HUJI
#
#   tagged_user_id tagged_user_name tagged_user_type  total_reactions  type  wow
# 0           None             None             None            103.0  POST  0.0
# 1           None             None             None             19.0  POST  0.0
# 2           None             None             None             17.0  POST  0.0
# 3           None             None             None             77.0  POST  0.0
# 4           None             None             None              7.0  POST  0.0

# %%
df.groupby(["type"]).agg(["count"])["index"]
# Out:
#          count
# type
# COMMENT  51596
# POST      7409
# TAG      42505

# %%
u_df = df.groupby(["source"]).agg(["count"])["index"].reset_index().sort_values(["count"])
plt.plot(u_df["source"], u_df["count"])
plt.show()

# %%
ID_REGEX = "(#\d+|\d+#){1}"
df["id"] = df["message"].str.findall(ID_REGEX).str.get(0)
df["message"].str
df["reply_to"] = df["message"].str.findall(ID_REGEX).str.get(1)
df.head()
# Out:
#    index  angry              created_time  haha     id  like  love  \
# 0      0    0.0  2018-02-14T09:50:00+0000  28.0  #1130  74.0   1.0
# 1      1    0.0  2018-02-14T09:40:00+0000   3.0  #1129  16.0   0.0
# 2      2    0.0  2018-02-14T09:30:00+0000   0.0  #1128  17.0   0.0
# 3      3    0.0  2018-02-14T09:20:03+0000  17.0    NaN  58.0   2.0
# 4      4    0.0  2018-02-14T09:20:00+0000   2.0  #1127   5.0   0.0
#
#                                              message parent_id  sad source  \
# 0  #1130 הדבר הכי מביך שקרה לי עד כה- ישבתי בספרי...      None  0.0   HUJI
# 1  #1129 גברים וגברות היום ולנטיינז, זה הרגע שלכם...      None  0.0   HUJI
# 2  #1128 לכל מי שמתרץ את עניין הרמאויות וההעתקות ...      None  0.0   HUJI
# 3                                       יוזמה נהדרת!      None  0.0   HUJI
# 4  #1127 אולי מישהו ירים כבר את הכפפה ויפתח קבוצת...      None  0.0   HUJI
#
#   tagged_user_id tagged_user_name tagged_user_type  total_reactions  type  \
# 0           None             None             None            103.0  POST
# 1           None             None             None             19.0  POST
# 2           None             None             None             17.0  POST
# 3           None             None             None             77.0  POST
# 4           None             None             None              7.0  POST
#
#    wow reply_to
# 0  0.0      NaN
# 1  0.0      NaN
# 2  0.0      NaN
# 3  0.0      NaN
# 4  0.0      NaN

# %% [markdown]
# #### Get the replies for each comment

# %% [markdown]
# #### Get the name of the commenter (for each comment or reply)

# %% [markdown]
# #### Get the commenter gender

# %% [markdown]
# #### Get the posts a user reacted to or commented to

# %% [markdown]
# #### Get a list of the users commented or reacted

# %% [markdown]
# #### Calculate the feeling in each institute
